# %%
import seaborn as sns

# %%
# %matplotlib inline

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.distplot(tips['total_bill'])
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
sns.distplot(tips['total_bill'], kde = False) #kde false hide the line

# %%
sns.distplot(tips['total_bill'], kde = False, bins = 30)

# %%
sns.jointplot(x = 'total_bill', y = 'tip', data = tips)

# %%
sns.jointplot(x = 'total_bill', y = 'tip', data = tips, kind = 'reg')
#by default kind is scatter.

# %%
sns.pairplot(tips) 
#it takes all data frame. When it is paring itself, it shows hist.

# %%
sns.pairplot(tips, hue ='sex')
#Hue colors the category

# %%
sns.pairplot(tips, hue ='sex', palette = 'coolwarm') 
#palette changes color.

# %%
sns.rugplot(tips['total_bill']) 
#like histplot, it takes one set of data. unlike histplot, it shows each bin of the bill. 
#Instead of stacking everything together like histplot.

# %%
#Example: Normal Distribution

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# %%
#Create dataset
dataset = np.random.randn(25)

#Create rugplot
sns.rugplot(dataset);

#Set up x-axis
x_min = dataset.min() - 2
x_max = dataset.max() + 2

#100 equally spaced point between x_min and x_max
x_axis = np.linspace(x_min, x_max, 100)

#Set up the bandwidth
bandwidth = ((4*dataset.std()**5)/(3*len(dataset)))**.2

#Create an empty kernel list
kernel_list = []

#Plot each basis function
for data_point in dataset:
    
    #Create a kernel for each point and append to list
    kernel = stats.norm(data_point, bandwidth).pdf(x_axis)
    kernel_list.append(kernel)
    
    #Scale for plotting
    kernel = kernel / kernel.max()
    kernel = kernel * .4
    plt.plot(x_axis, kernel, color = 'grey', alpha = 0.5)
    
plt.ylim(0, 1)
# Out:
# (0, 1)

# %%
#To get the KDE plot, sum basis functions

#Plot the sum of the basis function
sum_of_kde = np.sum(kernel_list, axis = 0)

#Plot figure
fig = plt.plot(x_axis, sum_of_kde, color = 'indianred')

#Add the initial rugplot
sns.rugplot(dataset, c = 'indianred')

#Remove y-tick marks
plt.yticks([])

#Set title
plt.suptitle("Sum of the Basis Function")
# Out:
# Text(0.5, 0.98, 'Sum of the Basis Function')

# %%
#Categorical Plot

# %%
sns.barplot(x = 'sex', y = 'total_bill', data = tips)
#by default the the estimation is average.

# %%
import numpy as np

# %%
sns.barplot(x = 'sex', y = 'total_bill', data = tips, estimator = np.std)

# %%
sns.countplot(x = 'sex', data = tips)
#The number of count per gender

# %%
sns.boxplot(x = 'day', y = 'total_bill', data = tips)
#Always in categorical x is category and y is numerical
#The points outside the box is outliers

# %%
sns.boxplot(x = 'day', y = 'total_bill', data = tips, hue = 'smoker')
#hue indicator to add another category

# %%
sns.boxplot(x = 'day', y = 'total_bill', data = tips, hue = 'sex')

# %%
sns.violinplot(x = 'day', y = 'total_bill', data = tips)
#plot all points including outliers.

# %%
sns.violinplot(x = 'day', y = 'total_bill', data = tips, hue = 'sex')

# %%
sns.violinplot(x = 'day', y = 'total_bill', data = tips, hue = 'sex', split = True)

# %%
sns.stripplot(x = 'day', y = 'total_bill', data = tips)

# %%
sns.stripplot(x = 'day', y = 'total_bill', data = tips, hue = 'sex')

# %%
sns.stripplot(x = 'day', y = 'total_bill', data = tips, hue = 'sex', split = True)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:2775: UserWarning: The `split` parameter has been renamed to `dodge`.
#   warnings.warn(msg, UserWarning)

# %%
sns.swarmplot(x = 'day', y = 'total_bill', data = tips)
#Like a combination of stripplot and violinplot
#Its not good to use this plot for large data set.

# %%
sns.violinplot(x = 'day', y = 'total_bill', data = tips)
sns.swarmplot(x = 'day', y = 'total_bill', data = tips, color = 'black')
#Plot violinplot on top of swarmplot
#Good for analysis and explore data but not good for presentation like boxplot.

# %%
sns.factorplot(x = 'day', y = 'total_bill', data = tips, kind = 'bar')
#use this for plot and add the plot you want in kind.
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
sns.factorplot(x = 'day', y = 'total_bill', data = tips, kind = 'violin')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\categorical.py:3666: UserWarning: The `factorplot` function has been renamed to `catplot`. The original name will be removed in a future release. Please update your code. Note that the default `kind` in `factorplot` (`'point'`) has changed `'strip'` in `catplot`.
#   warnings.warn(msg)

# %%
#Matrix Plot

# %%
import seaborn as sns
# %matplotlib inline
tips = sns.load_dataset('tips')
flights = sns.load_dataset('flights')
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
flights.head()
# Out:
#    year     month  passengers
# 0  1949   January         112
# 1  1949  February         118
# 2  1949     March         132
# 3  1949     April         129
# 4  1949       May         121

# %%
#Heatmap is the primary way to make a matrix plot. The dataset has to be in matrix form.
#The index name and the column and the cell values must match.
#Correlation data: The tips dataset does not work like that because the row name does not match the column name

# %%
#To do this, we can use corr

# %%
tips.corr()
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
tc = tips.corr()

# %%
sns.heatmap(tc)

# %%
sns.heatmap(tc, annot = True)
#To put annote the value

# %%
sns.heatmap(tc, cmap = 'coolwarm')

# %%
flights
# Out:
#      year      month  passengers
# 0    1949    January         112
# 1    1949   February         118
# 2    1949      March         132
# 3    1949      April         129
# 4    1949        May         121
# 5    1949       June         135
# 6    1949       July         148
# 7    1949     August         148
# 8    1949  September         136
# 9    1949    October         119
# 10   1949   November         104
# 11   1949   December         118
# 12   1950    January         115
# 13   1950   February         126
# 14   1950      March         141
# 15   1950      April         135
# 16   1950        May         125
# 17   1950       June         149
# 18   1950       July         170
# 19   1950     August         170
# 20   1950  September         158
# 21   1950    October         133
# 22   1950   November         114
# 23   1950   December         140
# 24   1951    January         145
# 25   1951   February         150
# 26   1951      March         178
# ...

# %%
#Convert into matrix

# %%
flights.pivot_table(index = 'month', columns = 'year', values = 'passengers')
# Out:
# year       1949  1950  1951  1952  1953  1954  1955  1956  1957  1958  1959  \
# month
# January     112   115   145   171   196   204   242   284   315   340   360
# February    118   126   150   180   196   188   233   277   301   318   342
# March       132   141   178   193   236   235   267   317   356   362   406
# April       129   135   163   181   235   227   269   313   348   348   396
# May         121   125   172   183   229   234   270   318   355   363   420
# June        135   149   178   218   243   264   315   374   422   435   472
# July        148   170   199   230   264   302   364   413   465   491   548
# August      148   170   199   242   272   293   347   405   467   505   559
# September   136   158   184   209   237   259   312   355   404   404   463
# October     119   133   162   191   211   229   274   306   347   359   407
# November    104   114   146   172   180   203   237   271   305   310   362
# ...

# %%
fp = flights.pivot_table(index = 'month', columns = 'year', values = 'passengers')

# %%
sns.heatmap(fp)

# %%
sns.heatmap(fp, cmap = 'magma', linecolor = 'white', linewidths = 1)

# %%
#Cluster version of the heatmap

# %%
sns.clustermap(fp, cmap = 'coolwarm')
#It is clustered to the similar data close to one another (e.g. like month and year here)

# %%
sns.clustermap(fp, cmap = 'coolwarm', standard_scale= 1)
#Standard_scale standardizes the values from zero to 1.
#Feb, Jan and Nov have less passengers, and july and june have the most.

# %%
#Grids

# %%
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
iris['species'].unique()
#Show the unique value
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
iris['sepal_length'].unique()
# Out:
# array([5.1, 4.9, 4.7, 4.6, 5. , 5.4, 4.4, 4.8, 4.3, 5.8, 5.7, 5.2, 5.5,
#        4.5, 5.3, 7. , 6.4, 6.9, 6.5, 6.3, 6.6, 5.9, 6. , 6.1, 5.6, 6.7,
#        6.2, 6.8, 7.1, 7.6, 7.3, 7.2, 7.7, 7.4, 7.9])

# %%
sns.pairplot(iris)

# %%
sns.PairGrid(iris)
#It gives an empty plot like subplot. Give you more control.

# %%
g = sns.PairGrid(iris)
g.map(plt.scatter)

# %%
g = sns.PairGrid(iris)
g.map_diag(sns.distplot)
g.map_upper(plt.scatter)
g.map_lower(sns.kdeplot)
#Choose what plot type we want in the grid.

# %%
tips = sns.load_dataset('tips')

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
g = sns.FacetGrid(data = tips, col = 'time', row = 'smoker')

# %%
g = sns.FacetGrid(data = tips, col = 'time', row = 'smoker')
#This takes the data and set the col and row of the grid.
g.map(sns.distplot, 'total_bill')
#And this add the data depending on the call. In this case its total bill.
#distplot only needs one arguement

#Separating time, smoker and their total bill

# %%
g = sns.FacetGrid(data = tips, col = 'time', row = 'smoker')
g.map(plt.scatter, 'total_bill', 'tip')

# %%
#Regression Plots

# %%
sns.lmplot(x = 'total_bill', y = 'tip', data = tips)

# %%
sns.lmplot(x = 'total_bill', y = 'tip', data = tips, hue = 'sex')

# %%
sns.lmplot(x = 'total_bill', y = 'tip', data = tips, hue = 'sex', 
           markers = ['o', 'v'], scatter_kws = {'s':100})
#Read the documentation for the style and the name like s for size

# %%
sns.lmplot(x = 'total_bill', y = 'tip', data = tips, col = 'sex')
#Separate the plot by sex in column

# %%
sns.lmplot(x = 'total_bill', y = 'tip', data = tips, row = 'sex')
#Separate the plot by sex in row

# %%
sns.lmplot(x = 'total_bill', y = 'tip', data = tips, 
           col = 'day', row = 'time', hue = 'sex')

# %%
sns.lmplot(x = 'total_bill', y = 'tip', data = tips, 
           col = 'day', row = 'time', hue = 'sex', 
           aspect = 0.6, size = 10)
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\regression.py:546: UserWarning: The `size` paramter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
#Style and Color

# %%
sns.set_style('darkgrid')
sns.countplot(x = 'sex', data = tips)

# %%
plt.figure(figsize = (12, 3)) # 12 x 3
sns.countplot(x = 'sex', data = tips)

# %%
sns.set_context('notebook', font_scale = 1) 
#The rest of the plots will follow this format.
sns.countplot(x = 'sex', data = tips)

# %%
sns.lmplot(x = 'total_bill', y = 'tip', data = tips, hue = 'sex',
          palette = 'seismic')
